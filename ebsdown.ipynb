# %%
import requests
import os

# %%
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/kor/elem_g4_s01_kor_4585.JPG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/kor/elem_g4_s01_kor_5269.JPG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/kor/elem_g4_s01_kor_4124.JPG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/kor/elem_g4_s01_kor_3972.JPG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/kor/elem_g4_s01_kor_3973.JPG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/kor/elem_g4_s01_kor_3974.JPG',
]

danwon = '초4-1학기-국어-7단원'
folder = '07. 사전은 내 친구'
os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPG')[0]+'.mp4'
    url2 = val.split('.JPG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#사회

danwon = '초4-1학기-사회-1단원'
folder = '01. 지역의 위치와 특성'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4767.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4770.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4772.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4774.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4775.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4776.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4777.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4778.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4781.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4780.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#사회 '',

danwon = '초4-1학기-사회-2단원'
folder = '02. 우리가 알아보는 지역의 역사'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4782.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4783.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4784.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4785.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4786.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4787.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4788.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4789.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#사회 '',

danwon = '초4-1학기-사회-3단원'
folder = '03. 지역의 공공 기관과 주민 참여'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4767.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4770.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4772.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4774.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4775.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4776.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4777.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4778.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4781.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/soc/elem_g4_s01_soc_4780.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초4-1학기-수학-1단원'
folder = '01. 큰 수'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6061.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6062.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6063.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6064.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6065.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6066.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPG')[0]+'.mp4'
    url2 = val.split('.JPG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초4-1학기-수학-2단원'
folder = '02. 각도'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6067.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6003.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_5470.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6004.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6038.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPG')[0]+'.mp4'
    url2 = val.split('.JPG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초4-1학기-수학-3단원'
folder = '03. 곱셈과 나눗셈'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_4469.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_4470.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_4471.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_5466.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_4486.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_5471.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_5472.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPG')[0]+'.mp4'
    url2 = val.split('.JPG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초4-1학기-수학-4단원'
folder = '04. 평면도형의 이동'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_3931.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_3932.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_3933.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_4022.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_4023.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_5468.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_5469.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPG')[0]+'.mp4'
    url2 = val.split('.JPG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초4-1학기-수학-5단원'
folder = '05. 막대그래프'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_13729.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_4473.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_13730.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPG')[0]+'.mp4'
    url2 = val.split('.JPG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초4-1학기-수학-6단원'
folder = '06. 규칙 찾기'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6009.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6010.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6034.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6035.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6036.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/mat/elem_g4_s01_mat_6037.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPG')[0]+'.mp4'
    url2 = val.split('.JPG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#과학 '',

danwon = '초4-1학기-과학-1단원'
folder = '01. 과학자처럼 탐구 해볼까요'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_8509.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#과학 '',

danwon = '초4-1학기-과학-2단원'
folder = '02. 지층과 화석'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4175.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4176.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4178.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4179.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4180.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4181.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#과학 '',

danwon = '초4-1학기-과학-3단원'
folder = '03. 식물의 한살이'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3833.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3834.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3835.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4182.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3836.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4183.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#과학 '',

danwon = '초4-1학기-과학-4단원'
folder = '04. 물체의 무게'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3837.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3838.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3839.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3840.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3841.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3842.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#과학 '',

danwon = '초4-1학기-과학-5단원'
folder = '05. 혼합물의 분리'
test = [
     'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4192.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4194.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3843.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3844.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_4197.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/sci/elem_g4_s01_sci_3845.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초4-1학기-영어-1단원'
folder = '01. I’m Happy'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4332.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4336.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4337.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4338.JPEG'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPEG')[0]+'.mp4'
    url2 = val.split('.JPEG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초4-1학기-영어-2단원'
folder = '02. This Is My Family'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4339.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4340.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4341.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4342.JPEG'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPEG')[0]+'.mp4'
    url2 = val.split('.JPEG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초4-1학기-영어-3단원'
folder = '03. Its Under the Desk'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4343.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4344.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4345.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4346.JPEG'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPEG')[0]+'.mp4'
    url2 = val.split('.JPEG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초4-1학기-영어-4단원'
folder = '04. What Time Is It'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4347.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4348.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4349.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4350.JPEG'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPEG')[0]+'.mp4'
    url2 = val.split('.JPEG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초4-1학기-영어-5단원'
folder = '05. Let’s Go Swimming'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4351.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4352.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4353.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4354.JPEG'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPEG')[0]+'.mp4'
    url2 = val.split('.JPEG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초4-1학기-영어-6단원'
folder = '06. I’m Studying'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4355.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4356.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4357.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4358.JPEG'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPEG')[0]+'.mp4'
    url2 = val.split('.JPEG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초4-1학기-영어-7단원'
folder = '07. I Get up Early'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4359.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4360.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4361.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4362.JPEG'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPEG')[0]+'.mp4'
    url2 = val.split('.JPEG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초4-1학기-영어-8단원'
folder = '08. What Do You Want'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4363.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4364.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4365.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4366.JPEG'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPEG')[0]+'.mp4'
    url2 = val.split('.JPEG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초4-1학기-영어-6단원'
folder = '09. Its Tuesday'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4367.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4368.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4369.JPEG',
    'https://content-cdn.edunet.net/edudata/content/elem/g4/s01/eng/elem_g4_s01_eng_4370.JPEG'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.JPEG')[0]+'.mp4'
    url2 = val.split('.JPEG')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#사회 '',

danwon = '초6-1학기-사회-1단원'
folder = '01. 우리나라의 정치 발전'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_14999.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15010.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15012.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15013.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15015.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15018.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_14458.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_14459.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_14460.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_14461.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_14462.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15022.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#사회 '',

danwon = '초6-1학기-사회-2단원'
folder = '02. 우리나라의 경제 발전'
test = [
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_14465.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_14466.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_24872.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15025.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15027.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15029.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15031.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15032.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_24871.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15035.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_15037.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/soc/elem_g6_s01_soc_24874.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초6-1학기-수학-1단원'
folder = '1. 분수의 나눗셈'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15727.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15729.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15728.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15730.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15732.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15731.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초6-1학기-수학-2단원'
folder = '2. 각기둥과 각뿔'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15824.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15738.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15741.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15743.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15744.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15745.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15747.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초6-1학기-수학-3단원'
folder = '3. 소수의 나눗셈'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15746.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15752.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15753.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15754.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15761.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15762.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15756.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_14482.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초6-1학기-수학-4단원'
folder = '4. 비와 비율'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15755.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15757.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15758.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15759.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15763.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15760.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초6-1학기-수학-5단원'
folder = '5. 여러 가지 그래프'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15733.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_14483.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15734.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15735.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15736.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#수학 '',

danwon = '초6-1학기-수학-6단원'
folder = '6. 직육면체의 부피와 겉넓이'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_14484.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15737.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15739.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15740.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/mat/elem_g6_s01_mat_15742.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#과학 '',

danwon = '초6-1학기-과학-1단원'
folder = '1. 과학자처럼 탐구해 볼까요'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14904.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#과학 '',

danwon = '초6-1학기-과학-2단원'
folder = '2. 지구와 달의 운동'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14905.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14906.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14907.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14908.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14909.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14910.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#과학 '',

danwon = '초6-1학기-과학-3단원'
folder = '3. 여러 가지 기체'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14911.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14912.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14913.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14921.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14922.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14923.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#과학 '',

danwon = '초6-1학기-과학-4단원'
folder = '4. 식물의 구조와 기능'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14924.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14925.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14926.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14931.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14934.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14936.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14943.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#과학 '',

danwon = '초6-1학기-과학-5단원'
folder = '5. 빛과 렌즈'
test = [
   'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14946.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14948.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14951.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14953.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/sci/elem_g6_s01_sci_14956.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초6-1학기-영어-1단원'
folder = '01. What Grade Are You In'
test = [
  'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14361.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14362.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14363.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14364.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14365.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14366.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초6-1학기-영어-2단원'
folder = '02. I Have a Headache'
test = [
  'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15057.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15058.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15059.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15060.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15061.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15062.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초6-1학기-영어-3단원'
folder = '03. Why Are You Happy'
test = [
  'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15063.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15064.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15065.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15066.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15067.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15068.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초6-1학기-영어-4단원'
folder = '04. When Is Your Birthday'
test = [
  'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14373.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14374.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14375.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14376.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14377.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14379.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초6-1학기-영어-5단원'
folder = '05. What Is She Wearing'
test = [
  'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15069.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15070.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15071.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15072.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15073.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15074.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초6-1학기-영어-6단원'
folder = '06. How Can I Get to the Museum'
test = [
  'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14406.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14408.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14410.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14412.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14415.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_14416.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초6-1학기-영어-7단원'
folder = '07. What Do You Think'
test = [
  'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15075.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15076.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15077.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15078.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15079.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15080.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
#영어 '',

danwon = '초6-1학기-영어-8단원'
folder = '08. How Often Do You Exercise'
test = [
  'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15081.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15082.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15083.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15084.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15085.jpg',
    'https://content-cdn.edunet.net/edudata/content/elem/g6/s01/eng/elem_g6_s01_eng_15086.jpg'
 ]

os.makedirs(os.path.join(folder))

for idx, val in enumerate(test):
    url = val.split('.jpg')[0]+'.mp4'
    url2 = val.split('.jpg')[0]+'.srt'
    r = requests.get(url, allow_redirects=True)
    r2 = requests.get(url2, allow_redirects=True)
    open(folder+'/'+danwon+'-'+str(idx)+'.mp4', 'wb').write(r.content)
    open(folder+'/'+danwon+'-'+str(idx)+'.srt', 'wb').write(r2.content)

# %%
https://cls2.edunet.net/cyber/ss/scca/pscc000a00.do
    /cyber/ss/sccb/pscc000b00.do 2334
